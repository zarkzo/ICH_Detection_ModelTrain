# %%
# !pip install tensorflow albumentations numpy pillow scikit-learn
# Out:
# Requirement already satisfied: tensorflow in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (2.10.1)
# Requirement already satisfied: albumentations in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (2.0.8)
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (2.0.2)
# Requirement already satisfied: pillow in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (11.3.0)
# Requirement already satisfied: scikit-learn in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (1.6.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.43.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.9)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.32.5)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.1.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.45.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (6.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2025.11.12)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from albumentations) (1.13.1)
# Requirement already satisfied: PyYAML in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from albumentations) (6.0.3)
# Collecting pydantic>=2.9.2 (from albumentations)
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting albucore==0.0.24 (from albumentations)
#   Using cached albucore-0.0.24-py3-none-any.whl.metadata (5.3 kB)
# Collecting eval-type-backport (from albumentations)
#   Using cached eval_type_backport-0.3.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opencv-python-headless>=4.9.0.80 (from albumentations)
#   Using cached opencv_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: stringzilla>=3.10.4 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from albucore==0.0.24->albumentations) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from albucore==0.0.24->albumentations) (6.5.12)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (8.7.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow) (3.23.0)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.9.2->albumentations)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from pydantic>=2.9.2->albumentations) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from pydantic>=2.9.2->albumentations) (0.4.2)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\lenovo\anaconda3\envs\tf_gpu\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (3.0.3)
# Using cached albucore-0.0.24-py3-none-any.whl (15 kB)
# Using cached opencv_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl (38.9 MB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached eval_type_backport-0.3.1-py3-none-any.whl (6.1 kB)
# Installing collected packages: opencv-python-headless, eval-type-backport, annotated-types, pydantic, albucore
#
#    ---------------------------------------- 0/5 [opencv-python-headless]
#    ---------------------------------------- 0/5 [opencv-python-headless]
#    ---------------------------------------- 0/5 [opencv-python-headless]
#    ---------------------------------------- 0/5 [opencv-python-headless]
#    ------------------------ --------------- 3/5 [pydantic]
#    ------------------------ --------------- 3/5 [pydantic]
#    ------------------------ --------------- 3/5 [pydantic]
#    ------------------------ --------------- 3/5 [pydantic]
#    ---------------------------------------- 5/5 [albucore]
#
# Successfully installed albucore-0.0.24 annotated-types-0.7.0 eval-type-backport-0.3.1 opencv-python-headless-4.12.0.88 pydantic-2.12.5

# %%
import albumentations as A
import cv2
import numpy as np
import os
from tqdm import tqdm
import pandas as pd
from sklearn.model_selection import train_test_split
import shutil

# %%
train_df = pd.read_csv(r"data_train_u.csv")

# %%
label_cols = ["any", "epidural", "intraparenchymal", "intraventricular", "subarachnoid", "subdural"]

# %%
max_count = 8000

# %%
src_dir = r"data_train_u"
aug_dir = r"data/data_train"
os.makedirs(aug_dir, exist_ok=True)

# %%
# Augmentasi dasar (rotasi, flip, brightness)
augment = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.RandomRotate90(p=0.05),
    A.ShiftScaleRotate(shift_limit=0.05, scale_limit=0.05, rotate_limit=5, p=0.7),
])
# Out:
# c:\Users\Lenovo\anaconda3\envs\tf_gpu\lib\site-packages\albumentations\core\validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)

# %%
# Tentukan jumlah target per kelas (misal mau samakan ke jumlah maksimum)
label_counts = {label: train_df[label].sum() for label in label_cols}

# %%
print("Jumlah awal per label:")
for lbl, cnt in label_counts.items():
    print(f"  {lbl}: {int(cnt)}")
# Out:
# Jumlah awal per label:
#   any: 36237
#   epidural: 2500
#   intraparenchymal: 14100
#   intraventricular: 11650
#   subarachnoid: 13589
#   subdural: 14294

# %%
# Hitung jumlah positif dan negatif di tiap label
for col in label_cols:
    counts = train_df[col].value_counts()
    total = counts.sum()
    positive = counts.get(1, 0)
    negative = counts.get(0, 0)
    balance_ratio = positive / total * 100
    print(f"{col:17} | Positif: {positive:5d} | Negatif: {negative:5d} | Rasio positif: {balance_ratio:6.2f}%")
# Out:
# any               | Positif: 36237 | Negatif:  8000 | Rasio positif:  81.92%
# epidural          | Positif:  2500 | Negatif: 41737 | Rasio positif:   5.65%
# intraparenchymal  | Positif: 14100 | Negatif: 30137 | Rasio positif:  31.87%
# intraventricular  | Positif: 11650 | Negatif: 32587 | Rasio positif:  26.34%
# subarachnoid      | Positif: 13589 | Negatif: 30648 | Rasio positif:  30.72%
# subdural          | Positif: 14294 | Negatif: 29943 | Rasio positif:  32.31%

# %%
aug_records = []

for label in label_cols:
    subset = train_df[train_df[label] == 1]
    needed = int(max_count - len(subset))
    if needed <= 0:
        continue

    print(f"\nAugmenting label '{label}' sebanyak {needed} gambar...")
    for i in tqdm(range(needed)):
        sample = subset.sample(1).iloc[0]
        img_path = os.path.join(src_dir, f"{sample['ImageID']}.png")

        img = cv2.imread(img_path)
        if img is None:
            continue

        aug_img = augment(image=img)["image"]
        new_name = f"{sample['ImageID']}_{label}_aug{i}"
        new_path = os.path.join(aug_dir, f"{new_name}.png")
        cv2.imwrite(new_path, aug_img)

        # Salin label dari sample asli
        aug_records.append({
            "ImageID": new_name,
            "any": sample["any"],
            "epidural": sample["epidural"],
            "intraparenchymal": sample["intraparenchymal"],
            "intraventricular": sample["intraventricular"],
            "subarachnoid": sample["subarachnoid"],
            "subdural": sample["subdural"],
        })
# Out:
# Augmenting label 'epidural' sebanyak 5500 gambar...
# 100%|██████████| 5500/5500 [01:00<00:00, 90.77it/s]

# %%
files = os.listdir(src_dir)

for f in tqdm(files, desc="Copying files", unit="file"):
    shutil.copy2(os.path.join(src_dir, f), os.path.join(aug_dir, f))

print("Balancing selesai. Semua data tersimpan di:", aug_dir)
# Out:
# Copying files: 100%|██████████| 44237/44237 [10:13<00:00, 72.05file/s]
# Balancing selesai. Semua data tersimpan di: data/data_train

# %%
# Gabungkan dataframe asli + augmentasi
aug_df = pd.DataFrame(aug_records)
train_balanced_df = pd.concat([train_df, aug_df], ignore_index=True)

# Simpan ke CSV baru
csv_path = os.path.join("data_train.csv")
train_balanced_df.to_csv(csv_path, index=False)

print(f"Total data setelah balancing: {len(train_balanced_df)}")
# Out:
# Total data setelah balancing: 49737

# %%
# Jumlah data sesudah
train_labels = pd.read_csv("train_labels.csv")

# Hitung jumlah positif dan negatif di tiap label
for col in label_cols:
    counts = train_labels[col].value_counts()
    total = counts.sum()
    positive = counts.get(1, 0)
    negative = counts.get(0, 0)
    balance_ratio = positive / total * 100
    print(f"{col:17} | Positif: {positive:5d} | Negatif: {negative:5d} | Rasio positif: {balance_ratio:6.2f}%")
# Out:
# any               | Positif: 41737 | Negatif:  8000 | Rasio positif:  83.92%
# epidural          | Positif:  8000 | Negatif: 41737 | Rasio positif:  16.08%
# intraparenchymal  | Positif: 15130 | Negatif: 34607 | Rasio positif:  30.42%
# intraventricular  | Positif: 12010 | Negatif: 37727 | Rasio positif:  24.15%
# subarachnoid      | Positif: 14569 | Negatif: 35168 | Rasio positif:  29.29%
# subdural          | Positif: 15576 | Negatif: 34161 | Rasio positif:  31.32%
